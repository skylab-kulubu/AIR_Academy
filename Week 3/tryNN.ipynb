# %%
import numpy as np
import pandas as pd
import random as r
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
data = []

for i in range(250):
    x1, x2 = r.uniform(-6, 6), r.uniform(-6, 6)

    if abs(x1) > 3 or abs(x2) > 3:
        label = 1
    else:
        label = 0

    data.append([x1, x2, label])

# %%
df = pd.DataFrame(data, columns=['x1', 'x2', 'y'])
cols = ['x1', 'x2']
df_x, df_y = df[cols], df['y']
df_x.head()
# Out:
#          x1        x2
# 0 -5.927781  0.640838
# 1  1.874337 -1.186014
# 2  0.848331  5.879340
# 3 -0.576151 -5.423338
# 4  5.335483  3.595283

# %%
model = Sequential([
    Dense(4, activation='relu', input_shape=(2,)),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(df_x, df_y, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 3ms/step - loss: 0.7149 - accuracy: 0.6080
# Epoch 2/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7062 - accuracy: 0.6360
# Epoch 3/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6988 - accuracy: 0.6520
# Epoch 4/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.6680
# Epoch 5/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6849 - accuracy: 0.6800
# Epoch 6/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6779 - accuracy: 0.6880
# Epoch 7/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6714 - accuracy: 0.7040
# Epoch 8/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6649 - accuracy: 0.7080
# Epoch 9/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6594 - accuracy: 0.7200
# Epoch 10/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6533 - accuracy: 0.7480
# Epoch 11/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6479 - accuracy: 0.7520
# Epoch 12/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6423 - accuracy: 0.7520
# Epoch 13/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6370 - accuracy: 0.7520
# Epoch 14/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6314 - accuracy: 0.7520
# Epoch 15/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6261 - accuracy: 0.7520
# Epoch 16/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6210 - accuracy: 0.7520
# Epoch 17/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6154 - accuracy: 0.7520
# Epoch 18/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6106 - accuracy: 0.7520
# Epoch 19/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6055 - accuracy: 0.7520
# Epoch 20/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6001 - accuracy: 0.7520
# Epoch 21/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5954 - accuracy: 0.7520
# Epoch 22/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5902 - accuracy: 0.7520
# Epoch 23/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5860 - accuracy: 0.7520
# Epoch 24/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5809 - accuracy: 0.7520
# Epoch 25/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5765 - accuracy: 0.7520
# Epoch 26/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5715 - accuracy: 0.7520
# Epoch 27/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5671 - accuracy: 0.7520
# Epoch 28/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5627 - accuracy: 0.7520
# Epoch 29/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5582 - accuracy: 0.7520
# Epoch 30/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5543 - accuracy: 0.7520
# Epoch 31/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5495 - accuracy: 0.7520
# Epoch 32/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5455 - accuracy: 0.7520
# Epoch 33/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5417 - accuracy: 0.7520
# Epoch 34/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5374 - accuracy: 0.7520
# Epoch 35/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5336 - accuracy: 0.7520
# Epoch 36/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5297 - accuracy: 0.7520
# Epoch 37/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5259 - accuracy: 0.7520
# Epoch 38/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5222 - accuracy: 0.7520
# Epoch 39/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5184 - accuracy: 0.7520
# Epoch 40/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5152 - accuracy: 0.7520
# Epoch 41/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5117 - accuracy: 0.7520
# Epoch 42/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5084 - accuracy: 0.7520
# Epoch 43/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5050 - accuracy: 0.7520
# Epoch 44/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5022 - accuracy: 0.7520
# Epoch 45/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4988 - accuracy: 0.7520
# Epoch 46/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4962 - accuracy: 0.7520
# Epoch 47/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4929 - accuracy: 0.7520
# Epoch 48/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4900 - accuracy: 0.7520
# Epoch 49/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4871 - accuracy: 0.7520
# Epoch 50/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4847 - accuracy: 0.7520

# %%
x1, x2 = -1, -2
xa = pd.DataFrame([x1, x2], columns = ['x1', 'x2'])
# model.predict(xa)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-1dda154b558a> in <cell line: 2>()
#       1 x1, x2 = -1, -2
# ----> 2 xa = pd.DataFrame([x1, x2], columns = ['x1', 'x2']).to_numpy()
#       3 model.predict(xa)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     760                     )
#     761                 else:
# --> 762                     mgr = ndarray_to_mgr(
#     763                         data,
#     764                         index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     347     )
#     348
# --> 349     _check_values_indices_shape_match(values, index, columns)
#     350
#     351     if typ == "array":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     418         passed = values.shape
#     419         implied = (len(index), len(columns))
# --> 420         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     421
#     422
#
# ValueError: Shape of passed values is (2, 1), indices imply (2, 2)
